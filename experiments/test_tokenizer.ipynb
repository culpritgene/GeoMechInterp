# %%
# Test sentencepiece in isolation
import tempfile
import os

# Create a temporary file with some sample text
with tempfile.NamedTemporaryFile(mode="w", delete=False, suffix=".txt") as f:
    f.write("This is a test sentence.\nAnother test sentence.")
    temp_filename = f.name

# Train a simple sentencepiece model
model_prefix = "test_sp"
# sentencepiece.SentencePieceTrainer.train(
#     f"--input={temp_filename} --model_prefix={model_prefix} "
#     "--vocab_size=19 --character_coverage=1.0"
# )

# # Load and test the model

# sp.load(f"{model_prefix}.model")

# Test encoding/decoding

# %%
import sentencepiece
sp = sentencepiece.SentencePieceProcessor()
model_prefix = "test_sp"
sp.Init(model_file=f"{model_prefix}.model")
sp.set_vocabulary(list_of_symbols)
test_text = "This is a test."
encoded = sp.encode_as_pieces(test_text)
decoded = sp.decode_pieces(encoded)

print("Original:", test_text)
print("Encoded:", encoded)
print("Decoded:", decoded)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 7
#       5 model_prefix = "test_sp"
#       6 list_of_symbols = ALL_SYMBOLS + EXTRA_SYMBOLS
# ----> 7 sp.Init(model_file=f"{model_prefix}.model")
#       8 sp.set_vocabulary(list_of_symbols)
#       9 test_text = "This is a test."
#
# File ~/miniconda3/envs/pytorch/lib/python3.11/site-packages/sentencepiece/__init__.py:468, in SentencePieceProcessor.Init(self, model_file, model_proto, out_type, add_bos, add_eos, reverse, emit_unk_piece, enable_sampling, nbest_size, alpha, num_threads)
#     466 self._num_threads = num_threads
#     467 if model_file or model_proto:
# --> 468   self.Load(model_file=model_file, model_proto=model_proto)
#
# File ~/miniconda3/envs/pytorch/lib/python3.11/site-packages/sentencepiece/__init__.py:961, in SentencePieceProcessor.Load(self, model_file, model_proto)
#     959 if model_proto:
#     960   return self.LoadFromSerializedProto(model_proto)
# --> 961 return self.LoadFromFile(model_file)
#
# File ~/miniconda3/envs/pytorch/lib/python3.11/site-packages/sentencepiece/__init__.py:316, in SentencePieceProcessor.LoadFromFile(self, arg)
#     315 def LoadFromFile(self, arg):
# --> 316     return _sentencepiece.SentencePieceProcessor_LoadFromFile(self, arg)
#
# OSError: Not found: "test_sp.model": No such file or directory Error #2

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /Users/solar/miniconda3/envs/pytorch/lib/python3.11/site-packages (0.2.0)

# %%
from geomechinterp.causal.mygpt import ALL_SYMBOLS, EXTRA_SYMBOLS
list_of_symbols = ALL_SYMBOLS + EXTRA_SYMBOLS

# %%
# !pip install sentencepiece --upgrade
# Out:
# Requirement already satisfied: sentencepiece in /Users/solar/miniconda3/envs/pytorch/lib/python3.11/site-packages (0.2.0)

# %%
from transformers import PreTrainedTokenizerFast

tokenizer = PreTrainedTokenizerFast(
    tokenizer_object=None,  # No internal tokenization logic
    vocab_list=list_of_symbols,
    unk_token="[UNK]",
    bos_token="[BOS]",
    eos_token="[EOS]",
    pad_token="[PAD]",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 from transformers import PreTrainedTokenizerFast
# ----> 3 tokenizer = PreTrainedTokenizerFast(
#       4     tokenizer_object=None,  # No internal tokenization logic
#       5     vocab_list=list_of_symbols,
#       6     unk_token="[UNK]",
#       7     bos_token="[BOS]",
#       8     eos_token="[EOS]",
#       9     pad_token="[PAD]",
#      10 )
#
# File ~/miniconda3/envs/pytorch/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:120, in PreTrainedTokenizerFast.__init__(self, *args, **kwargs)
#     118     fast_tokenizer = convert_slow_tokenizer(slow_tokenizer)
#     119 else:
# --> 120     raise ValueError(
#     121         "Couldn't instantiate the backend tokenizer from one of: \n"
#     122         "(1) a `tokenizers` library serialization file, \n"
#     123         "(2) a slow tokenizer instance to convert or \n"
#     124         "(3) an equivalent slow tokenizer class to instantiate and convert. \n"
#     125         "You need to have sentencepiece installed to convert a slow tokenizer to a fast one."
#     126     )
#     128 self._tokenizer = fast_tokenizer
#     130 if slow_tokenizer is not None:
#
# ValueError: Couldn't instantiate the backend tokenizer from one of:
# (1) a `tokenizers` library serialization file,
# (2) a slow tokenizer instance to convert or
# (3) an equivalent slow tokenizer class to instantiate and convert.
# You need to have sentencepiece installed to convert a slow tokenizer to a fast one.

# %%
from datasets import load_dataset
from geomechinterp.causal.mygpt import ALL_SYMBOLS, EXTRA_SYMBOLS
from geomechinterp.causal.mygpt import create_tokenize_function, SymbolTokenizer

data_path = "/Users/solar/Code/DL/Mechanistic_Interpretability/GeoMechInterp/data/all_patterns_and_generators_test.json"
# Create vocabulary and tokenizer
custom_vocab = ALL_SYMBOLS + EXTRA_SYMBOLS
tokenizer = SymbolTokenizer(custom_vocab)

# Load and process dataset
dataset = load_dataset(data_path)
tokenize_func = create_tokenize_function(tokenizer)
tokenized_dataset = dataset.map(tokenize_func, batched=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 11
#       8 tokenizer = SymbolTokenizer(custom_vocab)
#      10 # Load and process dataset
# ---> 11 dataset = load_dataset(data_path)
#      12 tokenize_func = create_tokenize_function(tokenizer)
#      13 tokenized_dataset = dataset.map(tokenize_func, batched=True)
#
# File ~/miniconda3/envs/pytorch/lib/python3.11/site-packages/datasets/load.py:2592, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2587 verification_mode = VerificationMode(
#    2588     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2589 )
#    2591 # Create a dataset builder
# -> 2592 builder_instance = load_dataset_builder(
#    2593     path=path,
#    2594     name=name,
#    2595     data_dir=data_dir,
#    2596     data_files=data_files,
#    2597     cache_dir=cache_dir,
#    2598     features=features,
#    2599     download_config=download_config,
#    2600     download_mode=download_mode,
#    2601     revision=revision,
#    2602     token=token,
#    2603     storage_options=storage_options,
#    2604     trust_remote_code=trust_remote_code,
#    2605     _require_default_config_name=name is None,
#    2606     **config_kwargs,
#    2607 )
#    2609 # Return iterable dataset in case of streaming
#    2610 if streaming:
#
# File ~/miniconda3/envs/pytorch/lib/python3.11/site-packages/datasets/load.py:2264, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, use_auth_token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    2262     download_config = download_config.copy() if download_config else DownloadConfig()
#    2263     download_config.storage_options.update(storage_options)
# -> 2264 dataset_module = dataset_module_factory(
#    2265     path,
#    2266     revision=revision,
#    2267     download_config=download_config,
#    2268     download_mode=download_mode,
#    2269     data_dir=data_dir,
#    2270     data_files=data_files,
#    2271     cache_dir=cache_dir,
#    2272     trust_remote_code=trust_remote_code,
#    2273     _require_default_config_name=_require_default_config_name,
#    2274     _require_custom_configs=bool(config_kwargs),
#    2275 )
#    2276 # Get dataset builder class from the processing script
#    2277 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/miniconda3/envs/pytorch/lib/python3.11/site-packages/datasets/load.py:1917, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1915             raise e1 from None
#    1916 else:
# -> 1917     raise FileNotFoundError(
#    1918         f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory."
#    1919     )
#
# FileNotFoundError: Couldn't find a dataset script at /Users/solar/Code/DL/Mechanistic_Interpretability/GeoMechInterp/data/all_patterns_and_generators_test.json/all_patterns_and_generators_test.json.py or any data file in the same directory.
