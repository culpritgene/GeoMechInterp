# %% [markdown]
# # High-Dimensional Curvature Measurement Demo
#
# This notebook demonstrates all curvature estimation methods for high-dimensional point cloud manifolds.
#
# ## Contents
# 1. Setup and Imports
# 2. Synthetic Manifold Generation
# 3. Curvature Methods Overview
# 4. Method 1: Local PCA Tangent Space Curvature
# 5. Method 2: Geodesic vs Euclidean Distance Ratio
# 6. Method 3: Local Intrinsic Dimension Estimation
# 7. Method 4: Ollivier-Ricci Curvature
# 8. Method 5: Sectional Curvature
# 9. Method 6: Covariance Derivative Method
# 10. Comparison of All Methods
# 11. Application: Neural Network Activations

# %% [markdown]
# ## 1. Setup and Imports
